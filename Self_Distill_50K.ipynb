# %% [markdown]
# # Self-Distillation to 50K — Drive-Safe
#
# Saves to Google Drive every 10 rounds. Runtime can die and data survives.

# %%
from google.colab import drive
drive.mount('/content/drive')
# !git clone https://github.com/MetaCortex-Dynamics/Axiom.git
# %cd Axiom
# !pip install -q torch tokenizers
import torch
print(f'GPU: {torch.cuda.get_device_name(0)}')
# Verify Drive is mounted
import os
assert os.path.exists('/content/drive/MyDrive'), 'Drive not mounted!'
print('Drive mounted. Data will survive runtime disconnect.')

# %%
# !python -m pipeline.distill.self_distill --rounds 200 --candidates 200 --device cuda
