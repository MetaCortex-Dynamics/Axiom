# %% [markdown]
# # Train Axiom 500M Decoder
#
# **PLAN-AXIOM-001 Phase 1** — 496M parameter decoder with protocol loss terms.
#
# Requirements: Colab Pro with A100 GPU. ~2-3 hours for 100 epochs.

# %%
# Setup
# !git clone https://github.com/MetaCortex-Dynamics/Axiom-Ref.git
# %cd Axiom-Ref
# !pip install -q torch tokenizers

import torch
print(f'GPU: {torch.cuda.get_device_name(0)}')
print(f'VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')

# %%
# Train
# !python scripts/train_500m.py

# %%
# Download the trained checkpoint
from google.colab import files
files.download('models/axiom-500m/decoder_best.pt')
